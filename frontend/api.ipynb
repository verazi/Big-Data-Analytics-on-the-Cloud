# %% [markdown]
# **COMP90024 – Team 75**
#
# - Linying Wei (1638206)
# - Wangyang Wu (1641248)
# - Ziyu Wang (1560831)
# - Roger Zhang (1079986)

# %%
from IPython.display import IFrame
IFrame(
    src="http://localhost:8000/api/visualize",
    width=1000,
    height=1000
)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="http://localhost:8000/api/visualize"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
kibana_url = "http://localhost:5601/goto/fca30970-34ba-11f0-8d0d-ef7b78f67d95"
IFrame(src=kibana_url, width="100%", height="1000")
# Out:
#         <iframe
#             width="100%"
#             height="1000"
#             src="http://localhost:5601/goto/fca30970-34ba-11f0-8d0d-ef7b78f67d95"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
